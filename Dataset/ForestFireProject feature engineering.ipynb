# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("algerian_forest_fire_with_features.csv")
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI  Classes  Temp_Humidity  Temp_Humidity_Ratio  Heat_Index
# 0  0.5        0           1653             0.508772      24.279
# 1  0.4        0           1769             0.475410      24.467
# 2  0.1        0           2132             0.317073      22.154
# 3  0.0        0           2225             0.280899      21.383
# 4  0.5        0           2079             0.350649      23.019

# %%
df.shape
# Out:
# (243, 17)

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Temp_Humidity',
#        'Temp_Humidity_Ratio', 'Heat_Index'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   day                  243 non-null    int64
#  1   month                243 non-null    int64
#  2   year                 243 non-null    int64
#  3   Temperature          243 non-null    int64
#  4   RH                   243 non-null    int64
#  5   Ws                   243 non-null    int64
#  6   Rain                 243 non-null    float64
#  7   FFMC                 243 non-null    float64
#  8   DMC                  243 non-null    float64
#  9   DC                   243 non-null    float64
#  10  ISI                  243 non-null    float64
#  11  BUI                  243 non-null    float64
#  12  FWI                  243 non-null    float64
#  13  Classes              243 non-null    int64
#  14  Temp_Humidity        243 non-null    int64
#  15  Temp_Humidity_Ratio  243 non-null    float64
#  16  Heat_Index           243 non-null    float64
# dtypes: float64(9), int64(8)
# memory usage: 32.4 KB

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Temp_Humidity',
#        'Temp_Humidity_Ratio', 'Heat_Index'],
#       dtype='object')

# %%
df['Classes'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.isnull().sum()
# Out:
# day                    0
# month                  0
# year                   0
# Temperature            0
# RH                     0
# Ws                     0
# Rain                   0
# FFMC                   0
# DMC                    0
# DC                     0
# ISI                    0
# BUI                    0
# FWI                    0
# Classes                0
# Temp_Humidity          0
# Temp_Humidity_Ratio    0
# Heat_Index             0
# dtype: int64

# %%
df = df[df['Classes'] != 'Classes']

# %%
df['Classes'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# day                    0
# month                  0
# year                   0
# Temperature            0
# RH                     0
# Ws                     0
# Rain                   0
# FFMC                   0
# DMC                    0
# DC                     0
# ISI                    0
# BUI                    0
# FWI                    0
# Classes                0
# Temp_Humidity          0
# Temp_Humidity_Ratio    0
# Heat_Index             0
# dtype: int64

# %%
df['Classes'] = df['Classes'].map({'not fire':0, 'fire':1})

# %%
print(df['Classes'].unique())
print(df['Classes'].value_counts())
# Out:
# [nan]
# Series([], Name: count, dtype: int64)

# %%
for column in df.columns:
    if column != 'Classes':
        df[column] = pd.to_numeric(df[column])

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   day                  243 non-null    int64
#  1   month                243 non-null    int64
#  2   year                 243 non-null    int64
#  3   Temperature          243 non-null    int64
#  4   RH                   243 non-null    int64
#  5   Ws                   243 non-null    int64
#  6   Rain                 243 non-null    float64
#  7   FFMC                 243 non-null    float64
#  8   DMC                  243 non-null    float64
#  9   DC                   243 non-null    float64
#  10  ISI                  243 non-null    float64
#  11  BUI                  243 non-null    float64
#  12  FWI                  243 non-null    float64
#  13  Classes              0 non-null      float64
#  14  Temp_Humidity        243 non-null    int64
#  15  Temp_Humidity_Ratio  243 non-null    float64
#  16  Heat_Index           243 non-null    float64
# dtypes: float64(10), int64(7)
# memory usage: 32.4 KB
# (243, 17)

# %%
df.to_csv("algerian_forest_fire_with_features.csv", index=False)

# %%
import numpy as np

# to make sure FWI is numeric
df['FWI'] = pd.to_numeric(df['FWI'], errors='coerce')

conditions = [
    (df['FWI'] < 5),
    (df['FWI'] >= 5) & (df['FWI'] < 15),
    (df['FWI'] >= 15)
]

risk_levels = ['Low', 'Moderate', 'Severe']

df['Fire_Risk'] = np.select(conditions, risk_levels, default='Low')

# %%
df['Fire_Risk_Label'] = df['Fire_Risk'].map({
    'Low':0,
    'Moderate':1,
    'Severe':2
})

# %%
print(df[['FWI','Fire_Risk','Fire_Risk_Label']])
# Out:
#      FWI Fire_Risk  Fire_Risk_Label
# 0    0.5       Low                0
# 1    0.4       Low                0
# 2    0.1       Low                0
# 3    0.0       Low                0
# 4    0.5       Low                0
# ..   ...       ...              ...
# 238  6.5  Moderate                1
# 239  0.0       Low                0
# 240  0.2       Low                0
# 241  0.7       Low                0
# 242  0.5       Low                0
#
# [243 rows x 3 columns]

# %%
print(df['Fire_Risk'].value_counts())
# Out:
# Fire_Risk
# Low         125
# Moderate     77
# Severe       41
# Name: count, dtype: int64

# %%
df.to_csv("algerian_forest_fire_with_features.csv", index=False)

# %%
df['Temp_Humidity'] = df['Temperature'] * df['RH']

# %%
df['Temp_Humidity_Ratio'] = df['Temperature'] / df['RH']

# %%
df['Heat_Index'] = 0.5 * (df['Temperature'] + 61.0 + ((df['Temperature']-68.0)*1.2) + (df['RH']*0.094))

# %%
df[['Temperature','RH','Temp_Humidity','Temp_Humidity_Ratio','Heat_Index']]
# Out:
#      Temperature  RH  Temp_Humidity  Temp_Humidity_Ratio  Heat_Index
# 0             29  57           1653             0.508772      24.279
# 1             29  61           1769             0.475410      24.467
# 2             26  82           2132             0.317073      22.154
# 3             25  89           2225             0.280899      21.383
# 4             27  77           2079             0.350649      23.019
# ..           ...  ..            ...                  ...         ...
# 238           30  65           1950             0.461538      25.755
# 239           28  87           2436             0.321839      24.589
# 240           27  87           2349             0.310345      23.489
# 241           24  54           1296             0.444444      18.638
# 242           24  64           1536             0.375000      19.108
#
# [243 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["Fire_Risk_Encoded"] = le.fit_transform(df["Fire_Risk"])

print("Label Encoding mapping:")
for cls, val in zip(le.classes_, range(len(le.classes_))):
    print(f"  {cls} -> {val}")
print()
print(df[["Fire_Risk", "Fire_Risk_Encoded"]].drop_duplicates().sort_values("Fire_Risk_Encoded"))
# Out:
# Label Encoding mapping:
#   Low -> 0
#   Moderate -> 1
#   Severe -> 2
#
#    Fire_Risk  Fire_Risk_Encoded
# 0        Low                  0
# 6   Moderate                  1
# 26    Severe                  2

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

cols_to_scale = ["Temperature", "RH", "Ws", "Rain", "FFMC", "DMC", "DC",
                 "ISI", "BUI", "FWI", "Temp_Humidity", "Temp_Humidity_Ratio", "Heat_Index"]

# Standard Scaling (mean=0, std=1)
scaler = StandardScaler()
df_scaled = df.copy()
df_scaled[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

print("Standard Scaled - first 5 rows:")
print(df_scaled[cols_to_scale].head())
print()
print("Mean after scaling (should be ~0):")
print(df_scaled[cols_to_scale].mean().round(4))
# Out:
# Standard Scaled - first 5 rows:
#    Temperature        RH        Ws      Rain      FFMC       DMC        DC  \
# 0    -0.870655 -0.340673  0.893277 -0.381657 -0.847927 -0.912120 -0.879401
# 1    -0.870655 -0.070359 -0.888877  0.268642 -0.938709 -0.855520 -0.879401
# 2    -1.699254  1.348788  2.319000  6.171355 -2.146802 -0.984891 -0.889913
# 3    -1.975454  1.821837 -0.888877  0.868918 -3.438694 -1.081920 -0.894117
# 4    -1.423054  1.010896  0.180416 -0.381657 -0.910776 -0.944463 -0.740651
#
#         ISI       BUI       FWI  Temp_Humidity  Temp_Humidity_Ratio  \
# 0 -0.830356 -0.936012 -0.880159      -0.805964            -0.257094
# 1 -0.902720 -0.900798 -0.893626      -0.501296            -0.403095
# 2 -1.071571 -0.985310 -0.934029       0.452106            -1.096020
# 3 -1.143935 -1.055737 -0.947497       0.696367            -1.254328
# 4 -0.854477 -0.900798 -0.880159       0.312905            -0.949081
#
#    Heat_Index
# 0   -1.038000
# 1   -0.985321
# 2   -1.633436
# 3   -1.849474
# 4   -1.391058
#
# Mean after scaling (should be ~0):
# Temperature           -0.0
# RH                     0.0
# Ws                    -0.0
# Rain                   0.0
# FFMC                   0.0
# DMC                   -0.0
# DC                     0.0
# ISI                   -0.0
# BUI                   -0.0
# FWI                   -0.0
# Temp_Humidity         -0.0
# Temp_Humidity_Ratio    0.0
# Heat_Index            -0.0
# dtype: float64

# %%
mm_scaler = MinMaxScaler()
df_minmax = df.copy()
df_minmax[cols_to_scale] = mm_scaler.fit_transform(df[cols_to_scale])

print("MinMax Scaled - first 5 rows:")
print(df_minmax[cols_to_scale].head())
print()
print("Min values (should be 0):")
print(df_minmax[cols_to_scale].min())
print("Max values (should be 1):")
print(df_minmax[cols_to_scale].max())
# Out:
# MinMax Scaled - first 5 rows:
#    Temperature        RH        Ws      Rain      FFMC       DMC        DC  \
# 0         0.35  0.521739  0.521739  0.000000  0.550445  0.041411  0.003279
# 1         0.35  0.579710  0.304348  0.077381  0.531157  0.052147  0.003279
# 2         0.20  0.884058  0.695652  0.779762  0.274481  0.027607  0.000937
# 3         0.15  0.985507  0.304348  0.148810  0.000000  0.009202  0.000000
# 4         0.25  0.811594  0.434783  0.000000  0.537092  0.035276  0.034192
#
#         ISI       BUI       FWI  Temp_Humidity  Temp_Humidity_Ratio  \
# 0  0.068421  0.034380  0.016077       0.397711             0.157968
# 1  0.052632  0.041854  0.012862       0.453028             0.137134
# 2  0.015789  0.023916  0.003215       0.626133             0.038255
# 3  0.000000  0.008969  0.000000       0.670482             0.015665
# 4  0.063158  0.041854  0.016077       0.600858             0.059223
#
#    Heat_Index
# 0    0.348077
# 1    0.357691
# 2    0.239415
# 3    0.199990
# 4    0.283647
#
# Min values (should be 0):
# Temperature            0.0
# RH                     0.0
# Ws                     0.0
# Rain                   0.0
# FFMC                   0.0
# DMC                    0.0
# DC                     0.0
# ISI                    0.0
# BUI                    0.0
# FWI                    0.0
# Temp_Humidity          0.0
# Temp_Humidity_Ratio    0.0
# Heat_Index             0.0
# dtype: float64
# Max values (should be 1):
# Temperature            1.0
# RH                     1.0
# Ws                     1.0
# Rain                   1.0
# FFMC                   1.0
# DMC                    1.0
# DC                     1.0
# ISI                    1.0
# BUI                    1.0
# FWI                    1.0
# Temp_Humidity          1.0
# Temp_Humidity_Ratio    1.0
# Heat_Index             1.0
# dtype: float64

# %%
df_scaled.to_csv("forest_fire_scaled.csv", index=False)
print("Saved: forest_fire_scaled.csv")
print("Shape:", df_scaled.shape)
print("Columns:", df_scaled.columns.tolist())
# Out:
# Saved: forest_fire_scaled.csv
# Shape: (243, 20)
# Columns: ['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Temp_Humidity', 'Temp_Humidity_Ratio', 'Heat_Index', 'Fire_Risk', 'Fire_Risk_Label', 'Fire_Risk_Encoded']
